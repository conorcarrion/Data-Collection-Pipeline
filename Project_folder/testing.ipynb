# %%
import my_webscraper

# %%
def output_list_to_text_file(url_list):
    with open('url_list_test.text', 'w') as l:
        pass

    with open('url_list_test.text', 'a') as l:
        l.write(str(url_list))


testlist = ['a', 'b', 'c', 'd']

output_list_to_text_file(testlist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/conor/Documents/Scratch/Data Collection/Project_folder/testing.ipynb Cell 2' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000004?line=5'>6</a>         l.write(url_list)
#       <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000004?line=8'>9</a> testlist = ['a', 'b', 'c', 'd']
# ---> <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000004?line=10'>11</a> output_list_to_text_file(testlist)
#
# /home/conor/Documents/Scratch/Data Collection/Project_folder/testing.ipynb Cell 2' in output_list_to_text_file(url_list)
# ...
