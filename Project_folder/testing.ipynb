# %%
import my_webscraper
import os
from my_webscraper import FileManager

# %%
file = 'c_40_single-malt-scotch-whisky?psize=2500&sort=nasc'
p = os.path.join('raw_data', file, f'{file}.text')
f = FileManager.unpack_text_to_python_list(p)
print(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/conor/Documents/Scratch/Data Collection/Project_folder/testing.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000001?line=0'>1</a> file = 'c_40_single-malt-scotch-whisky?psize=2500&sort=nasc/'
#       <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000001?line=1'>2</a> p = os.path.join('raw_data', file, f'{file}.text')
# ----> <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000001?line=2'>3</a> f = FileManager.unpack_text_to_python_list(p)
#       <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/Project_folder/testing.ipynb#ch0000001?line=3'>4</a> print(f)
#
# ...
