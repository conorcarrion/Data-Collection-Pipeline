# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument('--headless')


driver = webdriver.Chrome()
URL = 'https://en.wikipedia.org/wiki/Koala'
driver.get(URL)

# %%
h3 = driver.find_element(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/h3[2]')

# %%
h3.find_element(By.XPATH, './span').text
# Out:
# 'Foraging and activities'

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
import requests
r = requests.get('https://en.wikipedia.org/wiki/Dog')

# %%
r.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
print(soup.get_text())

# %%
soup.find('span', {'id': 'Health_and_mortality'}).text
# Out:
# 'Health and mortality'

# %%
handmspan = soup.find('span', {'id': 'Health_and_mortality'})
h3 = handmspan.find_parent()
p = h3.find_next_sibling()
len(p)
# Out:
# 56

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
# from selenium.webdriver.chrome.options import Options

# options = Options()
# options.add_argument('--headless')
# add options=options to webdriver.Chrome to run in headless mode
# use to quit driver in headless mode: driver.quit()

driver = webdriver.Chrome()
URL = 'https://www.zoopla.co.uk/for-sale/houses/richmond-upon-thames-london-borough/?beds_max=2&beds_min=2&property_sub_type=terraced&view_type=list&q=Richmond%20upon%20Thames%20(London%20Borough)%2C%20London&results_sort=newest_listings&search_source=home'
driver.get(URL)

# %%
prices = driver.find_elements_by_id('//data-testid="listing-price"')
# Out:
# /tmp/ipykernel_38264/1381498064.py:1: DeprecationWarning: find_elements_by_id is deprecated. Please use find_elements(by=By.ID, value=id_) instead
#   prices = driver.find_elements_by_id('//data-testid="listing-price"')
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# /home/conor/Documents/Scratch/Data Collection/seleniumtest/seleniumdemo.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/seleniumtest/seleniumdemo.ipynb#ch0000012?line=0'>1</a> prices = driver.find_elements_by_id('//data-testid="listing-price"')
#
# File ~/miniconda3/envs/webscraping/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:501, in WebDriver.find_elements_by_id(self, id_)
#     481 """
#     482 Finds multiple elements by id.
#     483
#    (...)
#     494         elements = driver.find_elements_by_id('foo')
# ...
