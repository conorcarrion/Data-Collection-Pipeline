# %%
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/conor/Documents/Scratch/Data Collection/seleniumtest/seleniumdemo.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/seleniumtest/seleniumdemo.ipynb#ch0000000?line=0'>1</a> import selenium
#
# ModuleNotFoundError: No module named 'selenium'

# %%
from selenium.webdriver import Chrome
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/conor/Documents/Scratch/Data Collection/seleniumtest/seleniumdemo.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/conor/Documents/Scratch/Data%20Collection/seleniumtest/seleniumdemo.ipynb#ch0000001?line=0'>1</a> from selenium.webdriver import Chrome
#
# ModuleNotFoundError: No module named 'selenium'
